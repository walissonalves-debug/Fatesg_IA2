# %%
# !pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/959.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/959.2 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/959.2 kB ? eta -:--:--
#    ---------- ----------------------------- 262.1/959.2 kB ? eta -:--:--
#    -------------------- ----------------- 524.3/959.2 kB 542.3 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/959.2 kB 638.9 kB/s eta 0:00:01
#    ---------------------------------------- 959.2/959.2 kB 686.0 kB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
#    ---------------------------------------- 0/2 [dnspython]
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongodb://localhost:27017/')
filter ={}

# %%
result = client['local']['startup_log'].find(
    filter=filter
)

# %%
df = pd.DataFrame(list(result))

# %%
display(df)
# Out:
#                            _id Item_Identifier  Item_Weight Item_Fat_Content  \
# 0     69c57bdd4aa6df9543f54fdf           FDA15        9.300          Low Fat
# 1     69c57bdd4aa6df9543f54fe0           DRC01        5.920          Regular
# 2     69c57bdd4aa6df9543f54fe1           FDN15       17.500          Low Fat
# 3     69c57bdd4aa6df9543f54fe2           FDX07       19.200          Regular
# 4     69c57bdd4aa6df9543f54fe3           NCD19        8.930          Low Fat
# ...                        ...             ...          ...              ...
# 8518  69c57bde4aa6df9543f57125           FDF22        6.865          Low Fat
# 8519  69c57bde4aa6df9543f57126           FDS36        8.380          Regular
# 8520  69c57bde4aa6df9543f57127           NCJ29       10.600          Low Fat
# 8521  69c57bde4aa6df9543f57128           FDN46        7.210          Regular
# 8522  69c57bde4aa6df9543f57129           DRG01       14.800          Low Fat
#
# ...

# %%
import numpy as np

# %%
vetor = np.array([[1,2],[3,4],[5,6]])
vetor
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
vetor.shape
# Out:
# (3, 2)

# %%
vetor[2]
# Out:
# array([5, 6])

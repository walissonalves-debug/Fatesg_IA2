# %%
import numpy as np

# %%
matriz = np.array([[1,2,3,4,22],[5,6,7,8,25],[9,10,11,12,30],[13,14,15,16,35]])
matriz
# Out:
# array([[ 1,  2,  3,  4, 22],
#        [ 5,  6,  7,  8, 25],
#        [ 9, 10, 11, 12, 30],
#        [13, 14, 15, 16, 35]])

# %%
terceira_linha = matriz[2]
terceira_linha
# Out:
# array([ 9, 10, 11, 12, 30])

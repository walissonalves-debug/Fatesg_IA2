# %%
import pandas as pd

funcionarios = [
    {'nome': 'Ana' ,'cargo': 'Analista'},
    {'nome': 'Carlos' ,'cargo': 'Gerente', 'bonus': 500}
]

# %%
df = pd.DataFrame (funcionarios)

print(df)
# Out:
#      nome     cargo  bonus
# 0     Ana  Analista    NaN
# 1  Carlos   Gerente  500.0

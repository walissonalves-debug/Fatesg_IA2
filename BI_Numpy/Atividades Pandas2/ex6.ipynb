# %%
import pandas as pd

dados= {
    'Capital' : ['Brasilia','Buenos Aires', 'Santiago'],
    'populacao': [2000000, 15000000, 1000000]
    'Continente': ['America do sul', 'America do Sul', 'America do sul']
}

paises_df = pd.DataFrame(dados,index=['Brasil', 'Argentina','Chile'])

dados_brasil = paises_df.loc['Brasil']

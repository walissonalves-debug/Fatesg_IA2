# %%
import pandas as pd
import numpy as np

serie_vazia = pd.Series(dtype ='float64')

print("Tipo da Series :{type(serie_vazia)}")
print (f"Dtype padrão: {serie_vazia.dtype}")
# Out:
# Tipo da Series :{type(serie_vazia)}
# Dtype padrão: float64

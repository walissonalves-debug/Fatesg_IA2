# %%
import pandas as pd
dados ={
'Sede A' : [1560, 2000 , 5000],
'Sede B' : [1450, 180, 3250]
}
df = pd.DataFrame(dados)

df['Total Vendas'] = df['Sede A'] + df['Sede B']

# %%
df['Imposto'] = df["Sede A"]*0.1

print (df)
# Out:
#    Sede A  Sede B  Total Vendas  Imposto
# 0    1000    1500          2500    100.0
# 1    2500    1800          4300    250.0
# 2    3000    4200          7200    300.0

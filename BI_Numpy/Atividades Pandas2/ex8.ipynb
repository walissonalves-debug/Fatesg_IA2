# %%
import pandas as pd
import numpy as np

df_historico = pd.DataFrame({
    'Data': pd.date_range(start ='2026-01-01', periods=20),
    'Valor': np.random.randint(100,500, size=20)
})

# %%
df_selecao = df_historico [4:12]

print("Novo DataFrame (5° até a 12° linha):")
print(df_selecao)
# Out:
# Novo DataFrame (5° até a 12° linha):
#          Data  Valor
# 4  2026-01-05    310
# 5  2026-01-06    491
# 6  2026-01-07    301
# 7  2026-01-08    209
# 8  2026-01-09    256
# 9  2026-01-10    341
# 10 2026-01-11    378
# 11 2026-01-12    385

# %%
import pandas as pd

dados_carros ={
    'modelo': ['Gol', 'Onix', 'HB20', 'Corolla', 'Sentra', 'Civic'],
    'Marca': ['VW','Chevrolet', 'Hyundai', 'Toyota', 'Nissan','Honda'],
    'Ano': [2015, 2016 , 2017, 2018, 2019, 2020]
    }

# %%
df_carros = pd.DataFrame(dados_carros)

selecao = df_carros.iloc[3:5]

# %%
print("seleção dos carros:")
print(selecao)
# Out:
# seleção dos carros:
#     modelo   Marca   Ano
# 3  Corolla  Toyota  2018
# 4   Sentra  Nissan  2019

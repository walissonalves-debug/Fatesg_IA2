# %%
import pandas as pd

df_pessoal = pd.DataFrame ({
    'Funcionario': ['Maria','Mauricio','Carla', 'Diego', 'Joana'],
    'Salario': [2500,1930,5000,5500,6000]
})

# %%
print("Transposta")
print(df_pessoal.T)
# Out:
# Transposta
#                  0         1      2      3      4
# Funcionario  Maria  Mauricio  Carla  Diego  Joana
# Salario       2500      1930   5000   5500   6000

# %%
print("Tipos de Dados")
print(df_pessoal.dtypes)
# Out:
# Tipos de Dados
# Funcionario    object
# Salario         int64
# dtype: object

# %%
print(f"\nQuantidade total de elementos: {df_pessoal.size}")
# Out:
# Quantidade total de elementos: 10

# %%
print("\n Duas últimas linhas")
print(df_pessoal.tail(2))
# Out:
#  Duas últimas linhas
#   Funcionario  Salario
# 3       Diego     5500
# 4       Joana     6000

# %%
import pandas as pd
nomes = pd.Series(['Teclado', 'Mouse','Monitor'], index=['p1','p2','p3'])

precos = pd.Series([150.00 , 80.00, 1200.00], index = ['p1', 'p2','p3'])

# %%
df_produtos = pd.DataFrame({
    'Produto': nomes ,
    'Preço' : precos
})

print(df_produtos)
# Out:
#     Produto   Preço
# p1  Teclado   150.0
# p2    Mouse    80.0
# p3  Monitor  1200.0

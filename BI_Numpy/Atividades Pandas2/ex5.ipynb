# %%
import pandas as pd

dados = {
    'Nome': ['Carlos', 'Diana','Eduardo'],
    'CPF' : ['123456789', '65478393746','263840745893'],
    'Telefone' : ['99864-0001','98536-2032', '98765-0923'],
    'Cidade' : ['Sao Paulo', 'Goiás', ' Brasilia']
}

df_clientes = pd.DataFrame(dados)

# %%
del df_clientes['CPF']

coluna_removida = df_clientes.pop('Telefone')

# %%
print("Conteúdo da coluna 'Telefone' removida:")
print(coluna_removida)
# Out:
# Conteúdo da coluna 'Telefone' removida:
# 0    99864-0001
# 1    98536-2032
# 2    98765-0923
# Name: Telefone, dtype: object

# %%
print("\nDataFrame final (sem CPF e Telefone):")
print(df_clientes)
# Out:
# DataFrame final (sem CPF e Telefone):
#       Nome     Cidade
# 0   Carlos  Sao Paulo
# 1    Diana      Goiás
# 2  Eduardo   Brasilia
